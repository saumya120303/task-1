# %% [markdown]
# <a href="https://colab.research.google.com/github/saumya120303/task-1/blob/main/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

def get_title(soup):
    try:
        title = soup.find("span", attrs={"id": "productTitle", "class": "a-size-large product-title-word-break"})
        title_string = title.text.strip()
    except AttributeError:
        title_string = ""
    return title_string

def get_price(soup):
    try:
        price = soup.find("span", attrs={'class': "a-size-medium a-color-success"}).string.strip()
    except AttributeError:
        try:
            price = soup.find("span", attrs={'class': 'a-price-whole'}).string.strip()
        except:
            price = ""
    return price

def get_brand(soup):
    try:
        brand_string = soup.find("div", id="bylineInfo_feature_div").find("a", class_="a-link-normal").text.strip()

        # Check if brand_string contains "Visit" or "Store" and remove them if found
        if "Visit" in brand_string:
            brand_string = brand_string.replace("Visit", "").strip()
        if "Store" in brand_string:
            brand_string = brand_string.replace("Store", "").strip()

    except AttributeError:
        brand_string = ""

    return brand_string



    return manufacturer
def get_img_src(soup):
    try:
        img_tag = soup.find("div", id="imgTagWrapperId").find("img")
        img_src = img_tag['src']
    except AttributeError:
        img_src = ""
    return img_src

if __name__ == '__main__':
    # Add your user agent
    HEADERS = {'User-Agent': '', 'Accept-Language': 'en-US, en;q=0.5'}

    # List of webpage URLs
    URLS = [
        "https://www.amazon.com.au/dp/B01BIRVL6A",
        "https://www.amazon.com.au/dp/B00544A9SK",
        "https://www.amazon.com.au/dp/B00NKJZE4K",
        "https://www.amazon.com.au/dp/B08XNS9BFS",
        "https://www.amazon.ca/dp/B0CP9QSBKR",
        'https://www.amazon.co.uk/dp/B0CMCSYHZM',
        "https://www.amazon.com/dp/B0CQXMJ66Y",
        "https://www.amazon.com/dp/B0CRCRLT5T",
        "https://www.amazon.de/-/en/dp/B0CQK87DQ5",
        "https://www.amazon.de/-/en/dp/B0CQK5GH9M",
        "https://www.amazon.com.tr/dp/B0CSG29SGB",
        "https://www.amazon.com/dp/B0CH5BMM7M",
        "https://www.amazon.de/-/en/dp/B0CQD7BLRG",
        "https://www.amazon.de/-/en/dp/B0CQD3JRDZ",
        "https://www.amazon.de/-/en/dp/B0CQD5QQR6",
    ]

    # Initialize an empty list to store data for all products
    all_product_data = []

    # Iterate over each URL
    for url in URLS:
        # HTTP Request
        webpage = requests.get(url, headers=HEADERS)

        # Soup Object containing all data
        soup = BeautifulSoup(webpage.content, "html.parser")

        # Extract product information
        title = get_title(soup)
        price = get_price(soup)
        brand = get_brand(soup)
        img = get_img_src(soup)

        # Append the extracted data to the list
        all_product_data.append({'title': title, 'price': price, 'brand': brand, 'img': img})

    # Create DataFrame from the list of dictionaries
    amazon_df = pd.DataFrame(all_product_data)

    # Replace empty strings with NaN
    amazon_df.replace('', np.nan, inplace=True)

    # Print DataFrame
    print(amazon_df)
# Out:
#                                                 title  \
# 0   Lemsip Max Lemon Cold and Flu Decongestant Hot...
# 1   Disprin Original Fasting Acting Pain Relief Ta...
# 2   Gaviscon Dual Action Chewable Peppermint Heart...
# 3   Strepfen Intensive Honey & Lemon Throat Lozeng...
# 4                                                 NaN
# 5   Air Wick Aerosol-Free Automatic Air Freshener ...
# 6                                                 NaN
# 7                            Air Wick AREA_DEODORIZER
# 8   Air Wick Duftölflakon Nachfüller DUO Blooming ...
# 9   Air Wick Duo Fresh Spring Breeze Fragrance Oil...
# 10  Air Wick Elektrikli Oda Kokusu Yedek Şişe Vanilya
# 11  Air Wick Essential Mist Air Freshener Refill -...
# 12  Air Wick Feel-good Duo Scented Candle in Glass...
# 13  Air Wick Feel-good scented candle duo in glass...
# 14  Air Wick Feel-good Scented Candle in Glass - S...
#
#                         price                     brand  \
# 0   Temporarily out of stock.             Brand: Lemsip
# 1   Temporarily out of stock.            Brand: Disprin
# 2   Temporarily out of stock.              the Gaviscon
# 3      Currently unavailable.           Brand: Strepfen
# 4                         NaN                       NaN
# 5      Currently unavailable.            Brand: Airwick
# 6                         NaN                       NaN
# 7      Currently unavailable.           Brand: Air Wick
# 8      Currently unavailable.              the Air Wick
# 9   Temporarily out of stock.              the Air Wick
# 10      Şu anda mevcut değil.  Air Wick ’u ziyaret edin
# 11     Currently unavailable.              the Air Wick
# 12                   In stock              the Air Wick
# 13                        NaN              the Air Wick
# 14     Currently unavailable.              the Air Wick
#
#                                                   img
# 0   https://m.media-amazon.com/images/I/A1JANUL33b...
# 1   https://m.media-amazon.com/images/I/81Y03aKsYJ...
# 2   https://m.media-amazon.com/images/I/819w-FS5HI...
# 3   https://m.media-amazon.com/images/I/81KtzPlEuZ...
# 4                                                 NaN
# 5   https://m.media-amazon.com/images/I/01RmK+J4pJ...
# 6                                                 NaN
# 7   https://m.media-amazon.com/images/I/01RmK+J4pJ...
# 8   https://m.media-amazon.com/images/I/71-BZUFK4z...
# 9   https://m.media-amazon.com/images/I/71i9VYxm2B...
# 10  https://m.media-amazon.com/images/I/61hzIM57el...
# 11  https://m.media-amazon.com/images/I/81n2X1B4UP...
# 12  https://m.media-amazon.com/images/I/71eGzOgehQ...
# 13  https://m.media-amazon.com/images/I/71PXeH2JKS...
# 14  https://m.media-amazon.com/images/I/71sZ6lsxQB...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

def get_title(soup):
    try:
        title = soup.find("span", attrs={"id": "productTitle", "class": "a-size-large product-title-word-break"})
        title_string = title.text.strip()
    except AttributeError:
        title_string = ""
    return title_string

def get_price(soup):
    try:
        price = soup.find("span", attrs={'class': "a-size-medium a-color-success"}).string.strip()
    except AttributeError:
        try:
            price = soup.find("span", attrs={'class': 'a-price-whole'}).string.strip()
        except:
            price = ""
    return price

def get_brand(soup):
    try:
        brand_string = soup.find("div", id="bylineInfo_feature_div").find("a", class_="a-link-normal").text.strip()

        # Check if brand_string contains "Visit" or "Store" and remove them if found
        if "Visit" in brand_string:
            brand_string = brand_string.replace("Visit", "").strip()
        if "Store" in brand_string:
            brand_string = brand_string.replace("Store", "").strip()

    except AttributeError:
        brand_string = ""

    return brand_string

def get_img_src(soup):
    try:
        img_tag = soup.find("div", id="imgTagWrapperId").find("img")
        img_src = img_tag['src']
    except AttributeError:
        img_src = ""
    return img_src

if __name__ == '__main__':
    # Add your user agent
    HEADERS = {'User-Agent': '', 'Accept-Language': 'en-US, en;q=0.5'}

    # List of webpage URLs
    URLS = [
        "https://www.amazon.com.au/dp/B01BIRVL6A",
        "https://www.amazon.com.au/dp/B00544A9SK",
        "https://www.amazon.com.au/dp/B00NKJZE4K",
        "https://www.amazon.com.au/dp/B08XNS9BFS",
        "https://www.amazon.ca/dp/B0CP9QSBKR",
        'https://www.amazon.co.uk/dp/B0CMCSYHZM',
        "https://www.amazon.com/dp/B0CQXMJ66Y",
        "https://www.amazon.com/dp/B0CRCRLT5T",
        "https://www.amazon.de/-/en/dp/B0CQK87DQ5",
        "https://www.amazon.de/-/en/dp/B0CQK5GH9M",
        "https://www.amazon.com.tr/dp/B0CSG29SGB",
        "https://www.amazon.com/dp/B0CH5BMM7M",
        "https://www.amazon.de/-/en/dp/B0CQD7BLRG",
        "https://www.amazon.de/-/en/dp/B0CQD3JRDZ",
        "https://www.amazon.de/-/en/dp/B0CQD5QQR6",
    ]

    # Initialize an empty list to store data for all products
    all_product_data = []

    # Iterate over each URL
    for url in URLS:
        # HTTP Request
        webpage = requests.get(url, headers=HEADERS)

        # Soup Object containing all data
        soup = BeautifulSoup(webpage.content, "html.parser")

        # Extract product information
        title = get_title(soup)
        price = get_price(soup)
        brand = get_brand(soup)
        img = get_img_src(soup)

        # Append the extracted data to the list
        all_product_data.append({'title': title, 'price': price, 'brand': brand, 'img': img})

    # Create DataFrame from the list of dictionaries
    amazon_df = pd.DataFrame(all_product_data)

    # Replace empty strings with NaN
    amazon_df.replace('', np.nan, inplace=True)

    # Print DataFrame
    amazon_df['title'].replace('', np.nan, inplace=True)
    amazon_df = amazon_df.dropna(subset=['title'])
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)

# %%
amazon_df
# Out:
#                                                 title  \
# 0   Lemsip Max Lemon Cold and Flu Decongestant Hot...
# 1   Disprin Original Fasting Acting Pain Relief Ta...
# 2   Gaviscon Dual Action Chewable Peppermint Heart...
# 3   Strepfen Intensive Honey & Lemon Throat Lozeng...
# 4   Airwick Vibrant™ SCENTED OIL Air Freshener Plu...
# 5   Air Wick Aerosol-Free Automatic Air Freshener ...
# 7                            Air Wick AREA_DEODORIZER
# 8   Air Wick Duftölflakon Nachfüller DUO Blooming ...
# 9   Air Wick Duo Fresh Spring Breeze Fragrance Oil...
# 10  Air Wick Elektrikli Oda Kokusu Yedek Şişe Vanilya
# 11  Air Wick Essential Mist Air Freshener Refill -...
# 12  Air Wick Feel-good Duo Scented Candle in Glass...
# 13  Air Wick Feel-good scented candle duo in glass...
# 14  Air Wick Feel-good Scented Candle in Glass - S...
#
#                         price                     brand  \
# 0   Temporarily out of stock.             Brand: Lemsip
# 1   Temporarily out of stock.            Brand: Disprin
# 2   Temporarily out of stock.              the Gaviscon
# 3      Currently unavailable.           Brand: Strepfen
# 4                    In Stock               the Airwick
# 5      Currently unavailable.            Brand: Airwick
# 7      Currently unavailable.           Brand: Air Wick
# 8      Currently unavailable.              the Air Wick
# 9   Temporarily out of stock.              the Air Wick
# 10      Şu anda mevcut değil.  Air Wick ’u ziyaret edin
# 11     Currently unavailable.              the Air Wick
# 12                   In stock              the Air Wick
# 13                        NaN              the Air Wick
# 14     Currently unavailable.              the Air Wick
#
#                                                   img
# 0   https://m.media-amazon.com/images/I/A1JANUL33b...
# 1   https://m.media-amazon.com/images/I/81Y03aKsYJ...
# 2   https://m.media-amazon.com/images/I/819w-FS5HI...
# 3   https://m.media-amazon.com/images/I/81KtzPlEuZ...
# 4   https://m.media-amazon.com/images/I/816dWpHNdU...
# 5   https://m.media-amazon.com/images/I/01RmK+J4pJ...
# 7   https://m.media-amazon.com/images/I/01RmK+J4pJ...
# 8   https://m.media-amazon.com/images/I/71-BZUFK4z...
# 9   https://m.media-amazon.com/images/I/71i9VYxm2B...
# 10  https://m.media-amazon.com/images/I/61hzIM57el...
# 11  https://m.media-amazon.com/images/I/81n2X1B4UP...
# 12  https://m.media-amazon.com/images/I/71eGzOgehQ...
# 13  https://m.media-amazon.com/images/I/71PXeH2JKS...
# 14  https://m.media-amazon.com/images/I/71sZ6lsxQB...
